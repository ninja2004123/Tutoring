# %% [markdown]
# # Introduction to Python Programming

# %% [markdown]
# ##### print()
# built-in function that displays input value as text in the output

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print('This line will be printed')
# Out:
# This line will be printed

# %%
"Hello Python interpreter!"
# Out:
# 'Hello Python interpreter!'

# %% [markdown]
# ### Python characteristics
# - Dynamically typed
# - Interpreter-based
# - Automated garbage collection
# - It with a vast standard library

# %% [markdown]
# ## Variables
# Variables are often described as boxes you can store values in.
#
# ![Python-data-structure.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### Different types of data
# - Strings( x = 'Hello World')
# - Numeric(Integers(x = 2), Floats(x = 2.3))
# - Boolean(True, False)

# %% [markdown]
# #### Memory
# - Typically, an integer occupies four bytes, or 32 bits
# - If you want to store a number larger than 2,147,483,647, Python can do it, using the long int data type. Rather than allocating a fixed four bytes of memory for a long int variable, Python decides how many bytes to assign based on the actual size of the number.
# - The floating-point type (or “float type” for short) is used for numbers that have fractional parts or are too large to store in a long int that takes up a reasonable amount of memory. Typically, eight bytes are used for the Python floating type.
# -  depending on the content of a string, Python uses different encodings. Note that every string in Python takes additional 49-80 bytes of memory, where it stores supplementary information, such as hash, length, length in bytes, encoding type and string flags. That's why an empty string takes 49 bytes of memory.

# %%
#string
message = 'Hello World'

# %%
print(message)
# Out:
# Hello World

# %%
name = 'Aleksandar'
city = 'Skopje'

# %%
# number - integer (whole number)
age = 26

# %%
# number - float (decimal number)
height = 55.5

# %%
# bool
is_student = False

# %%
print(name)
print(city)
print(age)
print(height)
print(is_student)
# Out:
# Aleksandar
# Skopje
# 26
# 55.5
# False

# %% [markdown]
# #### Naming rules and advices
#
# 1. A variable can have a short name (like x and y) or a more `descriptive name` (age, carname, total_volume).
# 2. A variable name `must start with a letter` or the underscore character
# 3. A variable name `cannot start with a number`
# 4. A variable name `can only contain alpha-numeric characters and underscores` (A-z, 0-9, and _ )
# 5. Variable names are `case-sensitive` (age, Age and AGE are three different variables)
# 6. Avoid using Python keywords

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# good example
message1 = 'Welcome to FCSE'

# %%
# bad example
1message = 'Bye, see you next time'
# Out:
#   Cell In[12], line 2
#     1message = 'Bye, see you next time'
#     ^
# SyntaxError: invalid decimal literal

# %%
# good example
first_message = 'Hello'
print(first_message)
# Out:
# Hello

# %%
# good example
firstMessage = 'Hello'

# %%
# bad example
first message = 'Hello'
# Out:
#   Cell In[16], line 2
#     first message = 'Hello'
#           ^
# SyntaxError: invalid syntax

# %%
# bad example
print = print

# %% [markdown]
# #### Assign Value to Multiple Variables

# %%
a, b, c = 1, 2, 3

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
d, e, f = "white", "red", "green"
print(d)
print(e)
print(f)
# Out:
# white
# red
# green

# %% [markdown]
# ## Strings
# A data type used in Python and programming in general used to represent text! Strings can be interpreted as a collection of characters. Anything inside quotes is considered a string in Python, and you can use single '' or double "" quotes around your
# strings. Strings in Python are shown as the variable type `str`.

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
"wrap lot's of other quotes"
# Out:
# "wrap lot's of other quotes"

# %% [markdown]
# When you need a `multiline string` you can use three single quotes or three double quotes:

# %%
a = '''Multi
line
string'''

# %%
b  = """Multi
Line
String 2"""

# %%
print(a)
# Out:
# Multi
# line
# string

# %%
print(b)
# Out:
# Multi
# Line
# String 2

# %% [markdown]
# You can also include a `\` in your string to be able to include one of these quotes:

# %%
this_string = 'Simon\'s homework is done.'
print(this_string)
# Out:
# Simon's homework is done.

# %%
this_string = "Occam's Razor, put simply, states: \"the simplest solution is almost always the best.\""
print(this_string)
# Out:
# Occam's Razor, put simply, states: "the simplest solution is almost always the best."

# %% [markdown]
# ###### Built-in functions for strings
# - bool() - Returns the boolean value of the specified object
# - dir()  - Returns a list of the specified object's properties and methods
# - format() - Formats a specified value
# - input()  - Allowing user input
# - len()  - Returns the length of an object
# - sorted() - Returns a sorted list
# - type() - Retruns the type of an object
# ...

# %%
poraka = 'Welcome to Faculty of computer science and engineering'

# %%
bool(poraka)
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
len(poraka)
# Out:
# 54

# %%
print(sorted(poraka))
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', 'F', 'W', 'a', 'a', 'c', 'c', 'c', 'c', 'c', 'd', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'f', 'g', 'g', 'i', 'i', 'i', 'l', 'l', 'm', 'm', 'n', 'n', 'n', 'n', 'n', 'o', 'o', 'o', 'o', 'p', 'r', 'r', 's', 't', 't', 't', 'u', 'u', 'y']

# %% [markdown]
# ###### Python String Methods
# - capitalize()	- Converts the first character to upper case
# - count()		- Returns the number of times a specified value occurs in a string
# - endswith()	- Returns true if the string ends with the specified value
# - find()		- Searches the string for a specified value and returns the position of where it was found
# - format()	    - Formats specified values in a string
# - index()		- Searches the string for a specified value and returns the position of where it was found
# - join()		- Joins the elements of an iterable to the end of the string
# - lower()		- Converts a string into lower case
# - lstrip()	    - Returns a left trim version of the string
# - rstrip()	    - Returns a right trim version of the string
# - replace()	    - Returns a string where a specified value is replaced with a specified value
# - split()		- Splits the string at the specified separator, and returns a list
# - startswith()	- Returns true if the string starts with the specified value
# - strip()		- Removes the whitespaces at the beggining and the end of a string
# - title()		- Converts the first character of each word to upper case
# - upper()		- Converts a string into upper case

# %% [markdown]
# Let's take a look at the most used ones

# %%
name = 'Faculty of computer science and engineering'
a = ' FSCE   '

# %% [markdown]
# ###### upper ()

# %%
name.upper()
# Out:
# 'FACULTY OF COMPUTER SCIENCE AND ENGINEERING'

# %% [markdown]
# startswith()

# %%
name.startswith("Fac")
# Out:
# True

# %% [markdown]
# ######  strip()

# %%
a.strip()
# Out:
# 'FSCE'

# %%
a.lstrip()
# Out:
# 'FSCE   '

# %%
a.rstrip()
# Out:
# ' FSCE'

# %%
b = '__FCSE__'

# %% [markdown]
# Strip specific chars

# %%
b.strip('_')
# Out:
# 'FCSE'

# %%
b.lstrip('_')
# Out:
# 'FCSE__'

# %% [markdown]
# ###### title ()

# %%
name.title()
# Out:
# 'Faculty Of Computer Science And Engineering'

# %% [markdown]
# ##### lower()

# %%
name.lower()
# name = name.lower()
# Out:
# 'faculty of computer science and engineering'

# %% [markdown]
# count()

# %%
m = 'MATEMATIKA'

# %%
m.count('m')
# Out:
# 0

# %%
m.count('M')
# Out:
# 2

# %% [markdown]
# ###### replace()

# %%
name
# Out:
# 'Faculty of computer science and engineering'

# %%
name.replace('computer', 'python')
# Out:
# 'Faculty of python science and engineering'

# %% [markdown]
# ###### split()

# %%
name.split(' ')
# Out:
# ['Faculty', 'of', 'computer', 'science', 'and', 'engineering']

# %%
str = "11,18,12,13,1"
niza = str.split(",") # it produces a list of strings"

# %%
len(niza)
# Out:
# 5

# %%
niza
# Out:
# ['11', '18', '12', '13', '1']

# %%
print(niza[2])
# Out:
# 12

# %% [markdown]
# ### String Concatenation
# String Concatenation is combining strings. To concatenate, or combine, two strings you can use the + operator.

# %%
first_word = 'Hello'
second_word = 'There'

# %%
first_word + second_word
# Out:
# 'HelloThere'

# %%
first_word + ' ' + second_word
# Out:
# 'Hello There'

# %% [markdown]
# ### String Format and f-strings
# The format() method takes the passed arguments,  and places them in the string where the placeholders {} are:

# %%
name = 'aleksandar stojmenski'
job = 'teaching assistant'
work = 'faculty of computer science and engineering'

# %%
message = 'Hello my name is {} and I am a {} at {}'.format(name, job, work)
message
# Out:
# 'Hello my name is aleksandar stojmenski and I am a teaching assistant at faculty of computer science and engineering'

# %%
message = 'Hello my name is {} and I am a {} at {}'.format(name.title(), job.title(), work.title())

# %%
message
# Out:
# 'Hello my name is Aleksandar Stojmenski and I am a Teaching Assistant at Faculty Of Computer Science And Engineering'

# %% [markdown]
# You can also use f-strings to compose a message, and then assign the entire message to a variable

# %%
f'Hello my name is {name.title()} and I am a {job.title()} at {work.title()}'
# Out:
# 'Hello my name is Aleksandar Stojmenski and I am a Teaching Assistant at Faculty Of Computer Science And Engineering'

# %% [markdown]
# ## Numbers
# There are three numeric types in Python:
# - int - integer is a whole number, positive or negative, without decimals
# - float - "floating point number" is a number, positive or negative, containing one or more decimals
# - complex - written with a "j" as the imaginary part

# %% [markdown]
# Let’s first look at how Python manages integers, because they’re the simplest to work with.

# %% [markdown]
# #### Integers

# %%
print(2+4)
# Out:
# 6

# %%
print(10-7)
# Out:
# 3

# %%
4**2
# Out:
# 16

# %%
br = 876614663
br = br / 10000
print(br)
br = br % 10000
print(br)
print(int(br))

## 10 / 3 = 3 + ostatok 1
# Out:
# 87661.4663
# 7661.4663
# 7661

# %%
x = 1
y = 35656222554887711
z = -3255522

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ##### Float

# %%
a = 1.10
b = int(1.0) # casting
c = -35.59

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ##### Complex numbers

# %%
x = 3+5j
y = 5j
z = -5j

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# ##### You can convert from one type to another with the int(), float(), and complex() methods:

# %%
x = 1 # int
y = 2.8 # float

# %%
type(y)
# Out:
# float

# %%
type(int(y))
# Out:
# int

# %%
#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

# %%
print(x, a)
print(y, b)
print(x, c)
# Out:
# 1 1.0
# 2.8 2
# 1 (1+0j)

# %%
print(type(x), type(a))
print(type(y), type(b))
print(type(x), type(c))
# Out:
# <class 'int'> <class 'float'>
# <class 'float'> <class 'int'>
# <class 'int'> <class 'complex'>

# %% [markdown]
# When using numbers and analyzing data you will need to do some calculations. This can be done using the arithmetic operators Python offers us.
#
# Arithmetic Operators:

# %%
# Addition:
print('Addition:', 3 + 2)
# Subtraction:
print('Subtraction:', 3 - 2)
# Multiplication: 3 * 2
print('Multiplication:', 3*2)
# Division:       3 / 2
print('Division:', 3 / 2)
# Floor Division: 3 // 2
print('Floor Division:', 3 // 2)
# Exponent:       3 ** 2
print('Exponent:', 3 ** 2)
# Modulus:        3 % 2
print('Modulus1:', 3 % 2)
print('Modulus2:', 4 % 2)

#When doing arithmetic operations between an integer and a float, the results type is float:
print('Integer/float arithemtics:')
print(5+2.0)
print(5+2.3)
print(5*2.56)
# Out:
# Addition: 5
# Subtraction: 1
# Multiplication: 6
# Division: 1.5
# Floor Division: 1
# Exponent: 9
# Modulus1: 1
# Modulus2: 0
# Integer/float arithemtics:
# 7.0
# 7.3
# 12.8

# %% [markdown]
# Numbers also have their own methods that give us a lot of functionalities

# %% [markdown]
# ##### abs()
# Returns the absolute value of a number

# %%
m = -3.375778756

# %%
abs(m)
# Out:
# 3.375778756

# %% [markdown]
# ##### round(number, ndigits)
# Return number rounded to ndigits precision after the decimal point. If ndigits is omitted or is None, it returns the nearest integer to its input

# %%
round(m)
# Out:
# -3

# %%
round(5.75)
# Out:
# 6

# %%
int(5.75)
# Out:
# 5

# %%
round(m,5)
# Out:
# -3.37578

# %% [markdown]
# ## Booleans
# The bool data type holds one of the values True or False, which are often encoded as 1 or 0, respectively. There are 6 comparison operators that are common to see in order to obtain a bool value:

# %%
# Greater Than:
4 > 2
# Out:
# True

# %%
# Less Than
4 < 2
# Out:
# False

# %%
# Less or Equal
3 <= 3
# Out:
# True

# %%
# Greater or Equal
3 >= 4
# Out:
# False

# %%
3 == 3
# Out:
# True

# %%
3 = 3
# Out:
#   Cell In[65], line 1
#     3 = 3
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# Not Equal or Different
5 != 5
# Out:
# False

# %% [markdown]
# The results from a comparison is etiher a true or false value, which is BOOLEAN data type.
# Comparision operators will be used later on when we learn about conditions

# %%
x = input("Enter the value of x")
print(f'Value of x is {x}')
y = input("Enter the value of y")

x = int(x)
y = int(y)

print(f'X is bigger than Y: {x>y}')
print(f'X^Y = {x**y}')
print(f'X / Y = {x / y}')
print(f'X // Y = {x // y}')
print(f'X % Y = {x % y}')
# Out:
# Enter the value of x 5
# Value of x is 5
# Enter the value of y 7
# X is bigger than Y: False
# X^Y = 78125
# X / Y = 0.7142857142857143
# X // Y = 0
# X % Y = 5

# %% [markdown]
# # HOMEWORK

# %% [markdown]
# #### Exercises - string: (5pt)
# 1. Make a variable d whose value will be finki.ukim.mk
# 2. In the variable d, count how many times the character f appears.
# 3. Find the length of the variable d.
# 4. Display the variable d in upper cases.

# %% [markdown]
# #### Exercises - arithmetics: (10pt)
# Од стандарден влез се внесуваат три страни на триаголник (децимални броеви). Да се пресмета и испечати на екран периметарот и плоштината на триаголникот.
# Формула за пресметка на периметар: a+b+c
# Формула за пресметка на плоштина:
# s = (a+b+c)/2 => P = s*(s-a)*(s-b)*(s-c)

# %% [markdown]
# #### Exercises - string input and split: (15pt)
# Од стандарден влез се внесуваат име, презиме и дата на раѓање (во формат dd.mm.yyyy). Да се испечати името на месецот кога е роден внесениот студент.

# %%
# Answer here
import calendar

# hint:
siteMeseci = "Januari,Februari,Mart,April,Maj,Juni,Juli,Avgust,Septemvri,Oktomvri,Noemvri,Dekemvri"
# or:
month = calendar.month_name[number]
